# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb


# %matplotlib inline
# Set default fig size
plt.rcParams["figure.figsize"] = [8, 8]

# %% [markdown]
# # Data Preparation & Visualization CNN_4rows

# %% [markdown]
# ## 1. Load data
# ### 1.1 Load Original and "Faked" Train data

# %%
# load first batch of original train data
data_raw_original_1 = pd.read_csv("dataset/eband_original_collected_train_data_2019-10-20.csv")
print("Shape of data_raw_original_1:", data_raw_original_1.shape)

# load second (current) batch of original train data
data_raw_original_2 = pd.read_csv("dataset/eband_original_collected_train_data.csv")
print("Shape of data_raw_original_2:", data_raw_original_2.shape)

# append 1 and 2
data_raw_original = data_raw_original_1.append(data_raw_original_2)
print("Shape of data_raw_original:", data_raw_original.shape)

##################################################################

# load augmanted / faked data
data_raw_faked = pd.read_csv("dataset/eband_faked_train_data.csv")
data_raw_faked.drop("comment", axis=1, inplace = True)
print("Shape of data_raw_faked:", data_raw_faked.shape)

# APPEND FAKED data to original data
data_raw_original_and_faked = data_raw_original.append(data_raw_faked)
print("Shape of data_raw_original and faked:", data_raw_original_and_faked.shape)

####################################################################

# load Temp train data data ( unsure if this data shall be used as train data)
data_raw_temp = pd.read_csv("dataset/eband_TEMP_train_data.csv")
print("Shape of data_raw_temp:", data_raw_temp.shape)


# APPEND TEMP data to original and faked data
data_raw_train = data_raw_original_and_faked.append(data_raw_temp)

print("Shape of data_raw_train", data_raw_train.shape)
print("Number of training examples (m)",data_raw_train.shape[0]/96)
# Out:
# Shape of data_raw_original_1: (20352, 58)
# Shape of data_raw_original_2: (10848, 58)
# Shape of data_raw_original: (31200, 58)
# Shape of data_raw_faked: (5952, 58)
# Shape of data_raw_original and faked: (37152, 58)
# Shape of data_raw_temp: (2016, 58)
# Shape of data_raw_train (39168, 58)
# Number of training examples (m) 408.0

# %% [markdown]
# ## 2. Prepare and save EBAND DATASET

# %% [markdown]
# ### 2.1 Augment features

# %%
def augment_features(df):
    
    # IMPORTANT. DO NOT MODIFY THIS FUNCTION WITHOUT CHANGE IN ALL SCRIPTS !!!
    
    df ["rx_levels_metric"] = df ["ActualReceived_Level_x"] + df ["ActualReceived_Level_y"]
    
    df ["ModChanges_metric"] = (df ["ModChanges_x"] + df ["ModChanges_y"]) * 2
    
    df ["errors_metric"] = ((df ["SES_x"] + df ["SES_y"]) * 100) + ((df ["ES_x"] + df ["ES_y"]) * 10 )
    
    df ["UAS_metric"] = df ["UAS_x"] + df ["UAS_y"]
    
    df ["fading_vs_rx_metric"] = (-100 * df ["rx_levels_metric"]) - df ["fading_metric"]
    
    
    return df

# Call function above
eband_dataset_cnn_4 = augment_features(data_raw_train)



eband_dataset_cnn_4.shape
# Out:
# (39168, 63)

# %% [markdown]
# ### 2.2 Fix labels

# %%
def fix_labels(df):
    
    # The 15 minute Y label
    df["Y_15min"] = df["Y label"] # name in loades csv files is "Y label"
    
    df["Y_15min_text"] = "N/A"
    
    # change prediction classes from value (numbers) to text
    df.loc[df["Y label"] == 0, "Y_15min_text"]  = "0. No event"
    df.loc[df["Y label"] == 1, "Y_15min_text"]  = "1. Out of service."
    df.loc[df["Y label"] == 2, "Y_15min_text"]  = "2. HW restart."
    df.loc[df["Y label"] == 3, "Y_15min_text"]  = "3. Stuck on low modulation."
    df.loc[df["Y label"] == 4, "Y_15min_text"]  = "4. Unstable Ant. support / Wind."
    df.loc[df["Y label"] == 5, "Y_15min_text"]  = "5. Intermittent LOS problem."
    df.loc[df["Y label"] == 6, "Y_15min_text"]  = "6. LOS or Alignment problem."
    df.loc[df["Y label"] == 7, "Y_15min_text"]  = "7. Bad LOS or Alignment problem."
    df.loc[df["Y label"] == 8, "Y_15min_text"]  = "8. Rain."
    df.loc[df["Y label"] == 9, "Y_15min_text"]  = "9. Stuck on mid modulation."
    df.loc[df["Y label"] == 10, "Y_15min_text"] = "10. Wet snow."
    df.loc[df["Y label"] == 11, "Y_15min_text"] = "11. Equipment fault."
    df.loc[df["Y label"] == 12, "Y_15min_text"] = "12. Equipment fault far end."
    df.loc[df["Y label"] == 13, "Y_15min_text"] = "13. No or limited data."
    
    
    # Drop old labels
    df.drop(["Y label", "Y 2"] , axis=1, inplace=True)
    
    # Drop other columns not used
    df.drop([ "Time", "NeId", "NeType", "FailureDescription",
                                  "FarEnd_NeAlias","pred_group",
                                  "QAM1024_Strong", "QAM1024", "QAM1024_Light",
                                  "QAM2048_Strong", "QAM2048", "QAM2048_Light","QAM4096_Strong",
                                  "QAM4096", "QAM4096_Light"], axis=1, inplace=True )

    return df

eband_dataset_cnn_4 = fix_labels(eband_dataset_cnn_4)

# %% [markdown]
# ### 2.2 Save dataset so it can be used by models

# %%
# Save to csv, this file is used in "Visualization notebook"
eband_dataset_cnn_4.to_csv("dataset/sharp_dataset/eband_dataset_cnn_4.csv", sep=',', header=True, float_format='%.2f', index=False)

print("Shape of eband_dataset_cnn_4:", eband_dataset_cnn_4.shape)
# Out:
# Shape of eband_dataset_cnn_4: (39168, 48)

# %%
eband_dataset_cnn_4
# Out:
#           NeAlias  HalfBPSK_Strong  HalfBPSK  HalfBPSK_Light  BPSK_Strong  \
# 0     CC0850-MW01                0         0               0            0
# 1     CC0850-MW01                0         0               0            0
# 2     CC0850-MW01                0         0               0            0
# 3     CC0850-MW01                0         0               0            0
# 4     CC0850-MW01                0         0               0            0
# 5     CC0850-MW01                0         0               0            0
# 6     CC0850-MW01                0         0               0            0
# 7     CC0850-MW01                0         0               0            0
# 8     CC0850-MW01                0         0               0            0
# 9     CC0850-MW01                0         0               0            0
# 10    CC0850-MW01                0         0               0            0
# 11    CC0850-MW01                0         0               0            0
# 12    CC0850-MW01                0         0               0            0
# 13    CC0850-MW01                0         0               0            0
# 14    CC0850-MW01                0         0               0            0
# 15    CC0850-MW01                0         0               0            0
# 16    CC0850-MW01               -1        -1              -1           -1
# 17    CC0850-MW01                0         0               0            0
# 18    CC0850-MW01                0         0               0            0
# 19    CC0850-MW01                0         0               0            0
# 20    CC0850-MW01                0         0               0            0
# 21    CC0850-MW01                0         0               0            0
# 22    CC0850-MW01                0         0               0            0
# 23    CC0850-MW01                0         0               0            0
# 24    CC0850-MW01                0         0               0            0
# 25    CC0850-MW01                0         0               0            0
# 0               170           0              12550.0        7
# 1              5440         108              11902.0        7
# 2              8020          86              10100.0        7
# 3                 0           0               9163.0        7
# 4                 0           0              10454.0        7
# 5               220           0               9639.0        7
# 6               510           0               9951.0        7
# 7                 0           0              11625.0        7
# 8               120           0              11024.0        7
# 9               350           0              10273.0        7
# 10                0           0               9305.0        7
# 11                0           0               9345.0        7
# 12                0           0              11084.0        7
# 13                0           0              10304.0        7
# 14                0           0              10608.0        7
# 15                0           0              11296.0        7
# 16             -110          -1               6624.0       13
# 17                0           0              10742.0        7
# 18                0           0              10918.0        7
# 19             1870           0               9455.0        7
# 20                0           0              12059.0        7
# 21                0           0              11726.0        7
# 22                0           0              11731.0        7
# 23                0           0              12030.0        7
# 24                0           0              12067.0        7
# 25                0           0              12092.0        7
# 26              110           0              10085.0        7
# 27               10           0              11790.0        7
# 28              150           0              11741.0        7
# 29               10           0              11973.0        7
# ...             ...         ...                  ...      ...
# 1986              0           0               5420.0        0
# 1987              0           0               5420.0        0
# 1988              0           0               5420.0        0
# 1989              0           0               5420.0        0
# 1990              0           0               5420.0        0
# 1991              0           0               5420.0        0
# 1992              0           0               5420.0        0
# 1993              0           0               5420.0        0
# 1994              0           0               5420.0        0
# 1995              0           0               5420.0        0
# 1996              0           0               5420.0        0
# 1997              0           0               5420.0        0
# 1998              0           0               5420.0        0
# 1999              0           0               5420.0        0
# 2000              0           0               5420.0        0
# 2001              0           0               5420.0        0
# 2002              0           0               5420.0        0
# 2003              0           0               5420.0        0
# 2004              0           0               5420.0        0
# 2005              0           0               5420.0        0
# 2006              0           0               5420.0        0
# 2007              0           0               5420.0        0
# 2008              0           0               5420.0        0
# 2009              0           0               5420.0        0
# 2010              0           0               5420.0        0
# 2011              0           0               5420.0        0
# 2012              0           0               5420.0        0
# 2013              0           0               5420.0        0
# 2014              0           0               5420.0        0
# 2015              0           0               5420.0        0
#
#                           Y_15min_text
# 0     7. Bad LOS or Alignment problem.
# 1     7. Bad LOS or Alignment problem.
# 2     7. Bad LOS or Alignment problem.
# 3     7. Bad LOS or Alignment problem.
# 4     7. Bad LOS or Alignment problem.
# 5     7. Bad LOS or Alignment problem.
# 6     7. Bad LOS or Alignment problem.
# 7     7. Bad LOS or Alignment problem.
# 8     7. Bad LOS or Alignment problem.
# 9     7. Bad LOS or Alignment problem.
# 10    7. Bad LOS or Alignment problem.
# 11    7. Bad LOS or Alignment problem.
# 12    7. Bad LOS or Alignment problem.
# 13    7. Bad LOS or Alignment problem.
# 14    7. Bad LOS or Alignment problem.
# 15    7. Bad LOS or Alignment problem.
# 16             13. No or limited data.
# 17    7. Bad LOS or Alignment problem.
# 18    7. Bad LOS or Alignment problem.
# 19    7. Bad LOS or Alignment problem.
# 20    7. Bad LOS or Alignment problem.
# 21    7. Bad LOS or Alignment problem.
# 22    7. Bad LOS or Alignment problem.
# 23    7. Bad LOS or Alignment problem.
# 24    7. Bad LOS or Alignment problem.
# 25    7. Bad LOS or Alignment problem.
# 26    7. Bad LOS or Alignment problem.
# 27    7. Bad LOS or Alignment problem.
# 28    7. Bad LOS or Alignment problem.
# 29    7. Bad LOS or Alignment problem.
# ...                                ...
# 1986                       0. No event
# 1987                       0. No event
# 1988                       0. No event
# 1989                       0. No event
# 1990                       0. No event
# 1991                       0. No event
# 1992                       0. No event
# 1993                       0. No event
# 1994                       0. No event
# 1995                       0. No event
# 1996                       0. No event
# 1997                       0. No event
# 1998                       0. No event
# 1999                       0. No event
# 2000                       0. No event
# 2001                       0. No event
# 2002                       0. No event
# 2003                       0. No event
# 2004                       0. No event
# 2005                       0. No event
# 2006                       0. No event
# 2007                       0. No event
# 2008                       0. No event
# 2009                       0. No event
# 2010                       0. No event
# 2011                       0. No event
# 2012                       0. No event
# 2013                       0. No event
# 2014                       0. No event
# 2015                       0. No event
#
# [39168 rows x 48 columns]

# %% [markdown]
# ## 3. Data visualization

# %% [markdown]
# ## 3.1 Class distrubution 15min data label (to predict each 15 min period)

# %%
def class_distr(input_df):

    df = input_df.groupby(["Y_15min_text"]).agg( { 'NeAlias': 'count',
                "sum_errors":"mean", "UAS_x": "mean", "fading_metric":"mean",
                'rx_levels_metric': "mean" , "Y_15min": "mean"} )

    df["Number of train examples"] =  df["NeAlias"]
    df["For validation/ test (80/20)"] =  df["Number of train examples"]*0.2
    df["errors_average"] = df["sum_errors"].round(1)
    df["UAS_x_average"] = df["UAS_x"].round(1)
    df["fading_metric_average"] = df["fading_metric"].round(1)
    df["rx_levels_metric_average"] = df["rx_levels_metric"].round(1)
    
    df.drop(["NeAlias", "UAS_x", "sum_errors", "fading_metric", 'rx_levels_metric'], axis=1, inplace=True)
    df.sort_values(by="Y_15min", inplace=True)
    df.reset_index(inplace=True)


    df.set_index("Y_15min_text", inplace=True)
    return df

# %%
# Call function

view_class_distr_15min_cnn = class_distr(eband_dataset_cnn_4)
view_class_distr_15min_cnn
# Out:
#                                   Y_15min  Number of train examples  \
# Y_15min_text
# 0. No event                             0                     23276
# 1. Out of service.                      1                       675
# 2. HW restart.                          2                        25
# 3. Stuck on low modulation.             3                      1299
# 4. Unstable Ant. support / Wind.        4                      2311
# 5. Intermittent LOS problem.            5                       208
# 6. LOS or Alignment problem.            6                      5313
# 7. Bad LOS or Alignment problem.        7                      2610
# 8. Rain.                                8                       590
# 9. Stuck on mid modulation.             9                      1344
# 10. Wet snow.                          10                       185
# 11. Equipment fault.                   11                       531
# 12. Equipment fault far end.           12                       493
# 13. No or limited data.                13                       308
#
#                                   For validation/ test (80/20)  \
# Y_15min_text
# 0. No event                                             4655.2
# 1. Out of service.                                       135.0
# 2. HW restart.                                             5.0
# 3. Stuck on low modulation.                              259.8
# 4. Unstable Ant. support / Wind.                         462.2
# 5. Intermittent LOS problem.                              41.6
# 6. LOS or Alignment problem.                            1062.6
# 7. Bad LOS or Alignment problem.                         522.0
# 8. Rain.                                                 118.0
# 9. Stuck on mid modulation.                              268.8
# 10. Wet snow.                                             37.0
# 11. Equipment fault.                                     106.2
# 12. Equipment fault far end.                              98.6
# 13. No or limited data.                                   61.6
#
#                                   errors_average  UAS_x_average  \
# Y_15min_text
# 0. No event                                  0.1            0.1
# 1. Out of service.                          -1.5          756.2
# 2. HW restart.                              -1.8           72.2
# 3. Stuck on low modulation.                 -0.1            0.0
# 4. Unstable Ant. support / Wind.            57.5            3.8
# 5. Intermittent LOS problem.                26.3            2.3
# 6. LOS or Alignment problem.                 0.0            0.0
# 7. Bad LOS or Alignment problem.             1.3            0.1
# 8. Rain.                                     4.3            8.6
# 9. Stuck on mid modulation.                  0.0            0.0
# 10. Wet snow.                                9.3           76.4
# 11. Equipment fault.                        98.2            0.0
# 12. Equipment fault far end.               103.2            0.0
# 13. No or limited data.                     11.9           -0.6
#
#                                   fading_metric_average  \
# Y_15min_text
# 0. No event                                         5.2
# 1. Out of service.                              15104.9
# 2. HW restart.                                   1382.5
# 3. Stuck on low modulation.                      7711.2
# 4. Unstable Ant. support / Wind.                 1306.9
# 5. Intermittent LOS problem.                     1339.6
# 6. LOS or Alignment problem.                      156.2
# 7. Bad LOS or Alignment problem.                 1680.6
# 8. Rain.                                         1000.2
# 9. Stuck on mid modulation.                       450.0
# 10. Wet snow.                                    4368.7
# 11. Equipment fault.                                0.1
# 12. Equipment fault far end.                        0.0
# 13. No or limited data.                           176.5
#
#                                   rx_levels_metric_average
# Y_15min_text
# 0. No event                                          -56.9
# 1. Out of service.                                   -83.0
# 2. HW restart.                                       -54.3
# 3. Stuck on low modulation.                          -58.1
# 4. Unstable Ant. support / Wind.                     -64.3
# 5. Intermittent LOS problem.                         -82.4
# 6. LOS or Alignment problem.                         -78.9
# 7. Bad LOS or Alignment problem.                     -98.7
# 8. Rain.                                             -84.2
# 9. Stuck on mid modulation.                          -52.9
# 10. Wet snow.                                        -94.8
# 11. Equipment fault.                                 -55.0
# 12. Equipment fault far end.                         -55.0
# 13. No or limited data.                              -35.3

# %%
def heatmap_15min_class(df):
    df = df.groupby(["Y_15min_text"]).agg({ 
                "sum_errors":"mean",
                "ActualReceived_Level_x": "mean", "ModChanges_x":"mean", "UAS_x":"mean",
                "ActualReceived_Level_y": "mean", "ModChanges_y":"mean", "UAS_y": "mean",
                "hw_fault": "mean", "fading_metric": "mean",
                'rx_levels_metric':"mean" , 'ModChanges_metric': "mean",
                   'errors_metric':"mean", "UAS_metric" : "mean"
                    })

    
    df.reset_index(inplace=True)

    df.set_index("Y_15min_text", inplace=True)
    
    # Normalize by column:
    df = (df - df.mean()) / df.std()
    
    return df

heatmap_class = heatmap_15min_class(eband_dataset_cnn_4)

# %%
heat_map = sb.heatmap(heatmap_class , annot=True)
plt.show()

# %%
eband_dataset_cnn_4.shape
# Out:
# (39168, 48)

# %%
fading_metric = eband_dataset_cnn_4.loc[ eband_dataset_cnn_4["fading_metric"]  > 1  ]
fading_metric = fading_metric["fading_metric"]
fading_metric.hist()
plt.show()

# %%
errors_metric = eband_dataset_cnn_4.loc[ eband_dataset_cnn_4["errors_metric"]  > 1000 ]
errors_metric = errors_metric["errors_metric"]


errors_metric.hist()
plt.show()

# %%
errors_metric.plot(kind='density', subplots=False, layout=(3,3), sharex=False)
plt.show()

# %%
fading_metric.plot(kind='density', subplots=False, layout=(3,3), sharex=False)
